# %% [markdown]
# <font size="5"><b>Class to load data</b></font>

# %%
import json
class load_data:
    def __init__(self):
        pass
   
    '''
    function to iterate over list to form dict of examples with user defined number of classes (So that we do not repeat lines of code for train, val and test)
    input: json file, number of classes data to extract
    output: dictoinary with key as class and value as list of training examples
    '''

    def iterate_over_data(self, data_list, num_classes):
        data_list_num_classes_dict={}
        for training_example in data_list:
            if training_example[1] in data_list_num_classes_dict:
                temp_val=data_list_num_classes_dict[training_example[1]]
                temp_val.append(training_example[0])
            elif len(data_list_num_classes_dict) == num_classes:
                break
            else:
                data_list_num_classes_dict[training_example[1]]=[training_example[0]]

        return data_list_num_classes_dict
    
    '''
    function to load the data
    input: json file, number of classes data to extract
    output: dictionaries with key as class and value as list of examples
    '''
    def load_data_all_sets(self, file, num_classes):
        with open(file) as f:
            data_full = json.load(f)

        data_for_num_classes=self.iterate_over_data(data_full['train'], num_classes)
        data_for_num_classes_val=self.iterate_over_data(data_full['val'], num_classes)
        data_for_num_classes_test=self.iterate_over_data(data_full['test'], num_classes)

        print("---------train------------")
        for key,value in data_for_num_classes.items():
            print(key, len(value))

        print("---------val------------")
        for key,value in data_for_num_classes_val.items():
            print(key, len(value))

        print("---------test------------")
        for key,value in data_for_num_classes_test.items():
            print(key, len(value))

        return data_for_num_classes, data_for_num_classes_val, data_for_num_classes_test

# %%
load_data_obj=load_data()
data_for_20_classes, data_for_20_classes_val, data_for_20_classes_test=load_data_obj.load_data_all_sets('/home/aindani/loyal/oos-eval-master/data/data_full.json', 20)
# Out:
# ---------train------------
# translate 100
# transfer 100
# timer 100
# definition 100
# meaning_of_life 100
# insurance_change 100
# find_phone 100
# travel_alert 100
# pto_request 100
# improve_credit_score 100
# fun_fact 100
# change_language 100
# payday 100
# replacement_card_duration 100
# time 100
# application_status 100
# flight_status 100
# flip_coin 100
# change_user_name 100
# where_are_you_from 100
# ---------val------------
# translate 20
# transfer 20
# timer 20
# definition 20
# meaning_of_life 20
# insurance_change 20
# find_phone 20
# travel_alert 20
# pto_request 20
# improve_credit_score 20
# fun_fact 20
# change_language 20
# payday 20
# replacement_card_duration 20
# time 20
# application_status 20
# flight_status 20
# flip_coin 20
# change_user_name 20
# where_are_you_from 20
# ---------test------------
# translate 30
# transfer 30
# timer 30
# definition 30
# meaning_of_life 30
# insurance_change 30
# find_phone 30
# travel_alert 30
# pto_request 30
# improve_credit_score 30
# fun_fact 30
# change_language 30
# payday 30
# replacement_card_duration 30
# time 30
# application_status 30
# flight_status 30
# flip_coin 30
# change_user_name 30
# where_are_you_from 30

# %% [markdown]
# <font size="5"><b>Class to preprocess data</b></font>

# %%
import spacy
import unidecode
from word2number import w2n
from pycontractions import Contractions
import gensim.downloader as api

class data_preprocessing:
    
    def __init__(self, contraction_model="glove-twitter-25", spacy_model='en', deselect_words=['no', 'not']):
        self.nlp = spacy.load(spacy_model)
        # Choose model accordingly for contractions function
        self.model = api.load(contraction_model)
        # model = api.load("glove-twitter-100")
        # model = api.load("word2vec-google-news-300")

        self.cont = Contractions(kv_model=self.model)
        self.cont.load_models()

        # exclude words from spacy stopwords list
        self.deselect_stop_words = deselect_words
        for w in self.deselect_stop_words:
            self.nlp.vocab[w].is_stop = False
    
    def remove_whitespace(self, text):
        """remove extra whitespaces from text"""
        text = text.strip()
        return " ".join(text.split())


    def remove_accented_chars(self, text):
        """remove accented characters from text, e.g. café"""
        text = unidecode.unidecode(text)
        return text


    def expand_contractions(self, text):
        """expand shortened words, e.g. don't to do not"""
        text = list(self.cont.expand_texts([text], precise=True))[0]
        return text


    def text_preprocessing(self, text, accented_chars=True, contractions=True, 
                           convert_num=True, extra_whitespace=True, 
                           lemmatization=True, lowercase=True, punctuations=True, 
                           remove_num=True, special_chars=True, 
                           stop_words=True):
        """preprocess text with default option set to true for all steps"""

        if extra_whitespace == True: #remove extra whitespaces
            text = self.remove_whitespace(text)
        if accented_chars == True: #remove accented characters
            text = self.remove_accented_chars(text)
        if contractions == True: #expand contractions
            text = self.expand_contractions(text)
        if lowercase == True: #convert all characters to lowercase
            text = text.lower()

        doc = self.nlp(text) #tokenise text

        clean_text = []

        for token in doc:
            flag = True
            edit = token.text
            # remove stop words
            if stop_words == True and token.is_stop and token.pos_ != 'NUM': 
                flag = False
            # remove punctuations
            if punctuations == True and token.pos_ == 'PUNCT' and flag == True: 
                flag = False
            # remove special characters
            if special_chars == True and token.pos_ == 'SYM' and flag == True: 
                flag = False
            # remove numbers
            if remove_num == True and (token.pos_ == 'NUM' or token.text.isnumeric()) \
            and flag == True:
                flag = False
            # convert number words to numeric numbers
            if convert_num == True and token.pos_ == 'NUM' and flag == True:
                edit = w2n.word_to_num(token.text)
            # convert tokens to base form
            elif lemmatization == True and token.lemma_ != "-PRON-" and flag == True:
                edit = token.lemma_
            # append tokens edited and not removed to list 
            if edit != "" and flag == True:
                clean_text.append(edit)        
        return clean_text
    
    def run_data_preprocessing(self,data_for_20_classes_dict):
        training_examples=[]
        classes=[]
        classes_category_to_id={}
        for cur_index, (key, value) in enumerate(data_for_20_classes_dict.items()):
            classes_category_to_id[key]=cur_index
            for item in value:
                training_examples.append(self.text_preprocessing(item))
                classes.append(cur_index)

        return training_examples, classes, classes_category_to_id

# %%
data_preprocessing_obj=data_preprocessing()
clean_text=data_preprocessing_obj.text_preprocessing("transfer $20000 from my savings account to checking account")
print(clean_text)
training_examples, classes, classes_category_to_id = data_preprocessing_obj.run_data_preprocessing(data_for_20_classes)
val_examples, classes_val, classes_category_to_id_val = data_preprocessing_obj.run_data_preprocessing(data_for_20_classes_val)
test_examples, classes_test, classes_category_to_id_test = data_preprocessing_obj.run_data_preprocessing(data_for_20_classes_test)
# Out:
# INFO - 20:28:34: loading projection weights from /home/aindani/gensim-data/glove-twitter-25/glove-twitter-25.gz
# INFO - 20:29:07: loaded (1193514, 25) matrix from /home/aindani/gensim-data/glove-twitter-25/glove-twitter-25.gz
# ['transfer', 'saving', 'account', 'check', 'account']
# INFO - 20:29:07: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:07: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:07: built Dictionary(8 unique tokens: ['for', 'goodbye', 'hawaii', 'in', 'local']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:07: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:07: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:07: built Dictionary(8 unique tokens: ['for', 'goodbye', 'hawaii', 'in', 'local']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:07: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:07: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:07: built Dictionary(9 unique tokens: ['do', 'german', 'how', 'in', 'say']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:07: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:07: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:07: built Dictionary(9 unique tokens: ['do', 'german', 'how', 'in', 'say']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:08: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(11 unique tokens: ['bar', 'can', 'for', 'into', 'irish']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:08: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(11 unique tokens: ['bar', 'can', 'for', 'into', 'irish']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(8 unique tokens: ['do', 'how', 'in', 'say', 'spanish']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(8 unique tokens: ['do', 'how', 'in', 'say', 'spanish']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(8 unique tokens: ['do', 'how', 'in', 'it', 'say']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(8 unique tokens: ['do', 'how', 'in', 'it', 'say']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(8 unique tokens: ['do', 'how', 'in', 'it', 'say']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(7 unique tokens: ['chinese', 'do', 'how', 'in', 'say']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:08: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(7 unique tokens: ['chinese', 'do', 'how', 'in', 'say']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(12 unique tokens: ['account', 'another', 'from', 'money', 'one']...) from 2 documents (total 23 corpus positions)
# INFO - 20:29:08: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:08: built Dictionary(12 unique tokens: ['account', 'another', 'from', 'money', 'one']...) from 2 documents (total 23 corpus positions)
# INFO - 20:29:09: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(9 unique tokens: ['a', 'for', 'minutes', 'need', 'set']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:09: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(9 unique tokens: ['a', 'for', 'minutes', 'need', 'set']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:09: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(6 unique tokens: ['affiliate', 'meaning', 'of', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:09: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(6 unique tokens: ['affiliate', 'meaning', 'of', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:09: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(4 unique tokens: ['affiliate', 'definition', 'has', 'what']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:09: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(4 unique tokens: ['affiliate', 'definition', 'is', 'what']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(7 unique tokens: ['definition', 'of', 'poor', 'the', 'whats']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(7 unique tokens: ['definition', 'of', 'poor', 'the', 'whats']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:09: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:09: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:09: built Dictionary(6 unique tokens: ['analogy', 'definition', 'of', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['analogy', 'definition', 'of', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['definition', 'of', 'patriarchy', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['definition', 'of', 'patriarchy', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(7 unique tokens: ['a', 'fortnight', 'meaning', 'of', 'the']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(7 unique tokens: ['a', 'fortnight', 'meaning', 'of', 'the']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:10: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(5 unique tokens: ['meaning', 'of', 'the', 'has', 'what']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:10: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(5 unique tokens: ['meaning', 'of', 'the', 'is', 'what']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:10: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['definition', 'of', 'the', 'whats', 'has']...) from 2 documents (total 9 corpus positions)
# INFO - 20:29:10: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['definition', 'of', 'the', 'whats', 'is']...) from 2 documents (total 9 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(11 unique tokens: ['any', 'can', 'if', 'life', 'me']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(11 unique tokens: ['any', 'can', 'if', 'life', 'me']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['answer', 'existence', 'the', 'to', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['answer', 'existence', 'the', 'to', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['of', 'point', 'sentience', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['of', 'point', 'sentience', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['existence', 'of', 'purpose', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['existence', 'of', 'purpose', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['life', 'of', 'purpose', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['life', 'of', 'purpose', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(11 unique tokens: ['as', 'dumpster', 'fire', 'known', 'life']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(11 unique tokens: ['as', 'dumpster', 'fire', 'known', 'life']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(4 unique tokens: ['lifes', 'meaning', 'has', 'what']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(4 unique tokens: ['lifes', 'meaning', 'is', 'what']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['exactly', 'lifes', 'meaning', 'whats', 'has']...) from 2 documents (total 9 corpus positions)
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['exactly', 'lifes', 'meaning', 'whats', 'is']...) from 2 documents (total 9 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(7 unique tokens: ['life', 'meaning', 'of', 'the', 'this']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(7 unique tokens: ['life', 'meaning', 'of', 'the', 'this']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(10 unique tokens: ['life', 'meaning', 'of', 'on', 'take']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(10 unique tokens: ['life', 'meaning', 'of', 'on', 'take']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:10: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['anyways', 'of', 'point', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(6 unique tokens: ['anyways', 'of', 'point', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:10: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(9 unique tokens: ['life', 'like', 'me', 'meaning', 'of']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:10: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(9 unique tokens: ['life', 'like', 'me', 'meaning', 'of']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(7 unique tokens: ['life', 'meaning', 'my', 'of', 'the']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:10: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:10: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:10: built Dictionary(7 unique tokens: ['life', 'meaning', 'my', 'of', 'the']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:11: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(6 unique tokens: ['everything', 'of', 'point', 'the', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:11: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(6 unique tokens: ['everything', 'of', 'point', 'the', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:11: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(9 unique tokens: ['has', 'it', 'life', 'meaning', 'or']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:11: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(10 unique tokens: ['has', 'it', 'life', 'meaning', 'or']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:11: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(3 unique tokens: ['meaning', 'has', 'what']) from 2 documents (total 4 corpus positions)
# INFO - 20:29:11: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(3 unique tokens: ['meaning', 'is', 'what']) from 2 documents (total 4 corpus positions)
# INFO - 20:29:11: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(6 unique tokens: ['in', 'life', 'meaning', 'my', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:11: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(6 unique tokens: ['in', 'life', 'meaning', 'my', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(7 unique tokens: ['life', 'meaning', 'of', 'the', 'whats']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(7 unique tokens: ['life', 'meaning', 'of', 'the', 'whats']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:11: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(7 unique tokens: ['a', 'insurance', 'life', 'like', 'new']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:11: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(7 unique tokens: ['a', 'insurance', 'life', 'like', 'new']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:11: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(10 unique tokens: ['a', 'get', 'healthcare', 'like', 'new']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:11: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:11: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:11: built Dictionary(10 unique tokens: ['a', 'get', 'healthcare', 'like', 'new']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:12: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:12: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:12: built Dictionary(6 unique tokens: ['finding', 'fon', 'help', 'like', 'my']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:12: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:12: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:12: built Dictionary(6 unique tokens: ['finding', 'fon', 'help', 'like', 'my']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:13: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(8 unique tokens: ['be', 'can', 'in', 'nepal', 'safe']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:13: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(8 unique tokens: ['be', 'can', 'in', 'nepal', 'safe']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:13: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(11 unique tokens: ['a', 'alert', 'country', 'for', 'if']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:13: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(11 unique tokens: ['a', 'alert', 'country', 'for', 'if']...) from 2 documents (total 20 corpus positions)
# INFO - 20:29:13: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(11 unique tokens: ['a', 'alert', 'country', 'for', 'if']...) from 2 documents (total 21 corpus positions)
# INFO - 20:29:13: Removed 2 and 2 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(11 unique tokens: ['a', 'alert', 'country', 'for', 'if']...) from 2 documents (total 21 corpus positions)
# INFO - 20:29:13: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(13 unique tokens: ['a', 'alert', 'country', 'for', 'if']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:13: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(13 unique tokens: ['a', 'alert', 'country', 'for', 'if']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:13: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(13 unique tokens: ['a', 'alert', 'can', 'country', 'for']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:13: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(13 unique tokens: ['a', 'alert', 'can', 'country', 'for']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:13: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(13 unique tokens: ['a', 'and', 'be', 'between', 'for']...) from 2 documents (total 29 corpus positions)
# INFO - 20:29:13: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(13 unique tokens: ['a', 'and', 'be', 'between', 'for']...) from 2 documents (total 29 corpus positions)
# INFO - 20:29:13: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(14 unique tokens: ['a', 'be', 'dates', 'for', 'june']...) from 2 documents (total 35 corpus positions)
# INFO - 20:29:13: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(14 unique tokens: ['a', 'be', 'dates', 'for', 'june']...) from 2 documents (total 35 corpus positions)
# INFO - 20:29:13: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(6 unique tokens: ['go', 'like', 'on', 'to', 'vacation']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:13: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(6 unique tokens: ['go', 'like', 'on', 'to', 'vacation']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:13: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(7 unique tokens: ['a', 'like', 'make', 'request', 'to']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:13: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:13: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:13: built Dictionary(7 unique tokens: ['a', 'like', 'make', 'request', 'to']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:14: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(8 unique tokens: ['a', 'day', 'from', 'like', 'take']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:14: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(8 unique tokens: ['a', 'day', 'from', 'like', 'take']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:14: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(7 unique tokens: ['from', 'like', 'pto', 'schedule', 'some']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:14: Removed 3 and 3 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(7 unique tokens: ['from', 'like', 'pto', 'schedule', 'some']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:14: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(7 unique tokens: ['credit', 'improve', 'like', 'my', 'score']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:14: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(7 unique tokens: ['credit', 'improve', 'like', 'my', 'score']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:14: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(8 unique tokens: ['better', 'credit', 'like', 'make', 'my']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:14: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(8 unique tokens: ['better', 'credit', 'like', 'make', 'my']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:14: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(9 unique tokens: ['credit', 'find', 'improve', 'like', 'my']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:14: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(9 unique tokens: ['credit', 'find', 'improve', 'like', 'my']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:14: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(8 unique tokens: ['best', 'build', 'credit', 'the', 'to']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:14: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:14: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:14: built Dictionary(8 unique tokens: ['best', 'build', 'credit', 'the', 'to']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['about', 'an', 'fact', 'flamingos', 'interesting']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['about', 'an', 'fact', 'flamingos', 'interesting']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['about', 'an', 'interesting', 'rivers', 'tidbit']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['about', 'an', 'interesting', 'rivers', 'tidbit']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'eggs', 'fact', 'fun']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'eggs', 'fact', 'fun']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'fact', 'neat', 'twinkies']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'fact', 'neat', 'twinkies']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(10 unique tokens: ['a', 'about', 'adult', 'entertainment', 'fact']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:15: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(10 unique tokens: ['a', 'about', 'adult', 'entertainment', 'fact']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:15: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(10 unique tokens: ['a', 'about', 'fact', 'fun', 'hear']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:15: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(10 unique tokens: ['a', 'about', 'fact', 'fun', 'hear']...) from 2 documents (total 19 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(8 unique tokens: ['a', 'about', 'china', 'fact', 'good']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(8 unique tokens: ['a', 'about', 'china', 'fact', 'good']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(9 unique tokens: ['a', 'about', 'britain', 'fact', 'fun']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(9 unique tokens: ['a', 'about', 'britain', 'fact', 'fun']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'fact', 'fun', 'mythology']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'fact', 'fun', 'mythology']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(8 unique tokens: ['a', 'elephants', 'fact', 'fun', 'relating']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(8 unique tokens: ['a', 'elephants', 'fact', 'fun', 'relating']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(9 unique tokens: ['a', 'about', 'and', 'cool', 'dogs']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(9 unique tokens: ['a', 'about', 'and', 'cool', 'dogs']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:15: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(8 unique tokens: ['about', 'florida', 'hear', 'like', 'some']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:15: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(8 unique tokens: ['about', 'florida', 'hear', 'like', 'some']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'elephants', 'fact', 'fun']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:15: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:15: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:15: built Dictionary(7 unique tokens: ['a', 'about', 'elephants', 'fact', 'fun']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:16: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:16: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:16: built Dictionary(8 unique tokens: ['i', 'last', 'paid', 'the', 'time']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:16: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:16: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:16: built Dictionary(8 unique tokens: ['i', 'last', 'paid', 'the', 'time']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:16: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:16: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:16: built Dictionary(9 unique tokens: ['a', 'got', 'i', 'last', 'paycheck']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:16: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:16: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:16: built Dictionary(9 unique tokens: ['a', 'got', 'i', 'last', 'paycheck']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(5 unique tokens: ['my', 'next', 'paycheck', 'has', 'when']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(5 unique tokens: ['my', 'next', 'paycheck', 'is', 'when']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(3 unique tokens: ['payday', 'has', 'when']) from 2 documents (total 4 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(3 unique tokens: ['payday', 'is', 'when']) from 2 documents (total 4 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(5 unique tokens: ['my', 'next', 'payday', 'has', 'when']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(5 unique tokens: ['my', 'next', 'payday', 'is', 'when']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(10 unique tokens: ['a', 'card', 'credit', 'on', 'replacing']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(10 unique tokens: ['a', 'card', 'credit', 'on', 'replacing']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(9 unique tokens: ['a', 'card', 'new', 'on', 'the']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(9 unique tokens: ['a', 'card', 'new', 'on', 'the']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(12 unique tokens: ['a', 'card', 'credit', 'expected', 'have']...) from 2 documents (total 22 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(12 unique tokens: ['a', 'card', 'credit', 'expected', 'have']...) from 2 documents (total 22 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(18 unique tokens: ['a', 'card', 'credit', 'in', 'lag']...) from 2 documents (total 34 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(18 unique tokens: ['a', 'card', 'credit', 'in', 'lag']...) from 2 documents (total 34 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(16 unique tokens: ['a', 'card', 'get', 'lost', 'new']...) from 2 documents (total 30 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(16 unique tokens: ['a', 'card', 'get', 'lost', 'new']...) from 2 documents (total 30 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(13 unique tokens: ['a', 'arrive', 'card', 'for', 'it']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(13 unique tokens: ['a', 'arrive', 'card', 'for', 'it']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(12 unique tokens: ['a', 'card', 'come', 'eta', 'for']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(12 unique tokens: ['a', 'card', 'come', 'eta', 'for']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(13 unique tokens: ['a', 'arrive', 'average', 'card', 'for']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:17: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:17: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:17: built Dictionary(13 unique tokens: ['a', 'arrive', 'average', 'card', 'for']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(10 unique tokens: ['a', 'card', 'for', 'replacement', 'the']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(10 unique tokens: ['a', 'card', 'for', 'replacement', 'the']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:18: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(6 unique tokens: ['in', 'london', 'the', 'time', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:18: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(6 unique tokens: ['in', 'london', 'the', 'time', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:18: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(10 unique tokens: ['florida', 'in', 'now', 'right', 'set']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:18: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(10 unique tokens: ['florida', 'in', 'now', 'right', 'set']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:18: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(6 unique tokens: ['now', 'right', 'the', 'time', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:18: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(6 unique tokens: ['now', 'right', 'the', 'time', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:18: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:18: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:18: built Dictionary(6 unique tokens: ['current', 'in', 'the', 'time', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:18: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# ...
# INFO - 20:29:27: Removed 2 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(4 unique tokens: ['location', 'my', 'is', 'what']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:27: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(4 unique tokens: ['my', 'phone', 'has', 'where']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:27: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(4 unique tokens: ['my', 'phone', 'is', 'where']) from 2 documents (total 6 corpus positions)
# INFO - 20:29:27: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(6 unique tokens: ['a', 'like', 'request', 'to', 'vacation']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:27: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(6 unique tokens: ['a', 'like', 'request', 'to', 'vacation']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:27: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(7 unique tokens: ['credit', 'improve', 'method', 'score', 'the']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:27: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:27: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:27: built Dictionary(7 unique tokens: ['credit', 'improve', 'method', 'score', 'the']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['about', 'bees', 'interesting', 'something', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['about', 'bees', 'interesting', 'something', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['in', 'like', 'portuguese', 'speak', 'to']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['in', 'like', 'portuguese', 'speak', 'to']...) from 2 documents (total 11 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(8 unique tokens: ['be', 'in', 'language', 'like', 'spanish']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(8 unique tokens: ['be', 'in', 'language', 'like', 'spanish']...) from 2 documents (total 15 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(7 unique tokens: ['like', 'russian', 'to', 'use', 'using']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(7 unique tokens: ['like', 'russian', 'to', 'use', 'using']...) from 2 documents (total 13 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(9 unique tokens: ['date', 'last', 'my', 'on', 'pay']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(9 unique tokens: ['date', 'last', 'my', 'on', 'pay']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(9 unique tokens: ['a', 'is', 'next', 'paycheck', 'receive']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(9 unique tokens: ['a', 'is', 'next', 'paycheck', 'receive']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['day', 'for', 'me', 'pay', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['day', 'for', 'me', 'pay', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['day', 'my', 'next', 'pay', 'has']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(6 unique tokens: ['day', 'my', 'next', 'pay', 'is']...) from 2 documents (total 10 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(9 unique tokens: ['do', 'know', 'my', 'next', 'paycheck']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:28: Removed 1 and 1 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(9 unique tokens: ['do', 'know', 'my', 'next', 'paycheck']...) from 2 documents (total 17 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(10 unique tokens: ['card', 'company', 'credit', 'for', 'my']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:28: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:28: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:28: built Dictionary(10 unique tokens: ['card', 'company', 'credit', 'for', 'my']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(7 unique tokens: ['in', 'new', 'the', 'time', 'york']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(7 unique tokens: ['in', 'new', 'the', 'time', 'york']...) from 2 documents (total 12 corpus positions)
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(6 unique tokens: ['exact', 'the', 'time', 'whats', 'has']...) from 2 documents (total 9 corpus positions)
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(6 unique tokens: ['exact', 'the', 'time', 'whats', 'is']...) from 2 documents (total 9 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(5 unique tokens: ['current', 'the', 'time', 'has', 'what']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(5 unique tokens: ['current', 'the', 'time', 'is', 'what']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(11 unique tokens: ['application', 'card', 'credit', 'for', 'hsbc']...) from 2 documents (total 22 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(11 unique tokens: ['application', 'card', 'credit', 'for', 'hsbc']...) from 2 documents (total 22 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['by', 'delta', 'flight', 'of', 'status']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['by', 'delta', 'flight', 'of', 'status']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(9 unique tokens: ['airlines', 'flight', 'my', 'of', 'status']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(9 unique tokens: ['airlines', 'flight', 'my', 'of', 'status']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['flight', 'jetblue', 'my', 'of', 'status']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['flight', 'jetblue', 'my', 'of', 'status']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['flight', 'my', 'of', 'southwest', 'status']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['flight', 'my', 'of', 'southwest', 'status']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(9 unique tokens: ['airlines', 'american', 'flight', 'my', 'of']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(9 unique tokens: ['airlines', 'american', 'flight', 'my', 'of']...) from 2 documents (total 16 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['delta', 'flight', 'my', 'news', 'the']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(8 unique tokens: ['delta', 'flight', 'my', 'news', 'the']...) from 2 documents (total 14 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(10 unique tokens: ['afternoon', 'delta', 'flight', 'for', 'my']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(10 unique tokens: ['afternoon', 'delta', 'flight', 'for', 'my']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(13 unique tokens: ['airline', 'american', 'be', 'flight', 'it']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(13 unique tokens: ['airline', 'american', 'be', 'flight', 'it']...) from 2 documents (total 24 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(10 unique tokens: ['a', 'and', 'coin', 'flip', 'heads']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:29: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:29: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:29: built Dictionary(10 unique tokens: ['a', 'and', 'coin', 'flip', 'heads']...) from 2 documents (total 18 corpus positions)
# INFO - 20:29:30: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:30: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:30: built Dictionary(5 unique tokens: ['country', 'home', 'your', 'has', 'what']) from 2 documents (total 8 corpus positions)
# INFO - 20:29:30: Removed 1 and 0 OOV words from document 1 and 2 (respectively).
# INFO - 20:29:30: adding document #0 to Dictionary(0 unique tokens: [])
# INFO - 20:29:30: built Dictionary(5 unique tokens: ['country', 'home', 'your', 'is', 'what']) from 2 documents (total 8 corpus positions)

# %% [markdown]
# <font size="5"><b>Class with ML classifiers and evaluations metrics</b></font>

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

class evaluate_models:
    def __init__(self):
        pass
    
    def run_ml_models(self,X_train_features,X_test_features,y_train,y_test):
        logistic_model = LogisticRegression(n_jobs=1, C=1e5, max_iter=200)
        forest_model = RandomForestClassifier()
        linear_svm_model = SVC(kernel='linear')
        svm_model = SVC()
        knn_model = KNeighborsClassifier(n_neighbors=3)

        models = {"logistic_model":logistic_model,
                  "forest_model":forest_model
                  , "linear_svm_model":linear_svm_model,
                  "svm_model":svm_model,
                  "knn_model":knn_model}

        for model_name, model in models.items():
            print(model_name)
            reg = model
            reg = reg.fit(X_train_features, y_train)
            y_pred = reg.predict(X_test_features)
            print('accuracy %s' % accuracy_score(y_pred, y_test))
            print(classification_report(y_test, y_pred))

# %% [markdown]
# <font size="5"><b>Class for TFIDF experiment</b></font>

# %%
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.metrics import confusion_matrix

class tfidf_model:
    def __init__(self, training_examples, classes, val_examples, classes_val, test_examples, classes_test, classes_category_to_id):
        self.data_for_tfidf=[]
        self.data_for_tfidf_val=[]
        self.data_for_tfidf_test=[]
        self.classes=classes
        self.classes_val=classes_val
        self.classes_test=classes_test
        self.classes_category_to_id=classes_category_to_id
        
        for line in training_examples:
            str1 = " "
            self.data_for_tfidf.append(str1.join(line))
        for line in val_examples:
            str1 = " "
            self.data_for_tfidf_val.append(str1.join(line))
        for line in test_examples:
            str1 = " "
            self.data_for_tfidf_test.append(str1.join(line))
        
        self.tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', ngram_range=(1, 2))
        self.training_features = self.tfidf.fit_transform(self.data_for_tfidf).toarray()
        
        self.evaluate_models_obj=evaluate_models()

        
    def chi2_check_max_correlation(self, classes_category_to_id, N = 2):      
        for Product, category_id in sorted(classes_category_to_id.items()):
            features_chi2 = chi2(features, labels == category_id)
            indices = np.argsort(features_chi2[0])
            feature_names = np.array(tfidf.get_feature_names())[indices]
            unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
            bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
            print("# '{}':".format(Product))
            print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
            print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-N:])))
    
    def cross_validation(self, CV = 10):
        #adding validation data as well to do cross validation
        tfidf_val = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', ngram_range=(1, 2))
        features = tfidf_val.fit_transform(self.data_for_tfidf + self.data_for_tfidf_val).toarray()
        labels = np.array(self.classes + self.classes_val)

        models = [
            RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0),
            LinearSVC(),
            MultinomialNB(),
            LogisticRegression(random_state=0),
        ]    
        cv_df = pd.DataFrame(index=range(CV * len(models)))
        entries = []

        for model in models:
            model_name = model.__class__.__name__
            accuracies = cross_val_score(model, features, labels, scoring='accuracy', cv=CV)
            for fold_idx, accuracy in enumerate(accuracies):
                entries.append((model_name, fold_idx, accuracy))
        cv_df = pd.DataFrame(entries, columns=['model_name', 'fold_idx', 'accuracy'])


        
        sns.boxplot(x='model_name', y='accuracy', data=cv_df)
        sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
                      size=10, jitter=True, edgecolor="gray", linewidth=2)
        plt.show()
    
    def train_model(self, model = LinearSVC()):
        labels = np.array(self.classes)
        X_train = self.training_features
        y_train = np.reshape(labels,(labels.shape[0],1))
        model.fit(X_train, y_train)
        
        return model
    
    def plot_confusion(self,y_test, y_pred):
        conf_mat = confusion_matrix(y_test, y_pred)
        fig, ax = plt.subplots(figsize=(10,10))
        sns.heatmap(conf_mat, annot=True, fmt='d',
                    xticklabels=classes_category_to_id.keys(), yticklabels=classes_category_to_id.keys())
        plt.ylabel('Actual')
        plt.xlabel('Predicted')
        plt.show()
      
    def evaluate_model_different_ML_classifiers(self,model):     
        features_test = self.tfidf.transform(self.data_for_tfidf_test).toarray()    
        labels_test = np.array(self.classes_test)
        
        X_test = features_test
        y_test = np.reshape(labels_test,(labels_test.shape[0],1))
        y_pred = model.predict(X_test)
        
        print("---------------Cross-validation with different classifiers -----------------")
        self.cross_validation()
        
        print("---------------Plotting confusion matrix for best model as per CV-----------------")
        self.plot_confusion(y_test, y_pred)
        
        print("---------------Printing classification report -----------------")
        self.evaluate_models_obj.run_ml_models(self.training_features,features_test,self.classes,self.classes_test)
        
        #print(metrics.classification_report(y_test,y_pred, target_names=self.classes_category_to_id.keys()))

# %%
tfidf_model_obj=tfidf_model(training_examples, classes, val_examples, classes_val, test_examples, classes_test, classes_category_to_id)
trained_model=tfidf_model_obj.train_model()
tfidf_model_obj.evaluate_model_different_ML_classifiers(trained_model)
# Out:
# /home/aindani/.conda/envs/loyal/lib/python3.7/site-packages/sklearn/utils/validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ---------------Cross-validation with different classifiers -----------------
# ---------------Plotting confusion matrix for best model as per CV-----------------
# ---------------Printing classification report -----------------
# logistic_model
# /home/aindani/.conda/envs/loyal/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# accuracy 0.925
#               precision    recall  f1-score   support
#
#            0       0.88      0.70      0.78        30
#            1       0.97      0.97      0.97        30
#            2       1.00      1.00      1.00        30
#            3       0.90      0.93      0.92        30
#            4       0.93      0.90      0.92        30
#            5       1.00      0.93      0.97        30
#            6       0.97      1.00      0.98        30
#            7       1.00      0.97      0.98        30
#            8       1.00      1.00      1.00        30
#            9       1.00      1.00      1.00        30
#           10       1.00      0.93      0.97        30
#           11       0.90      0.90      0.90        30
#           12       1.00      0.93      0.97        30
#           13       1.00      0.87      0.93        30
#           14       1.00      0.93      0.97        30
#           15       0.88      1.00      0.94        30
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        30
#           18       0.50      0.90      0.64        30
#           19       0.95      0.63      0.76        30
#
#     accuracy                           0.93       600
#    macro avg       0.94      0.93      0.93       600
# weighted avg       0.94      0.93      0.93       600
#
# forest_model
# accuracy 0.9233333333333333
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84        30
#            1       1.00      0.97      0.98        30
#            2       1.00      1.00      1.00        30
#            3       0.88      0.97      0.92        30
#            4       0.93      0.87      0.90        30
#            5       1.00      0.93      0.97        30
#            6       1.00      1.00      1.00        30
#            7       0.97      0.97      0.97        30
#            8       1.00      1.00      1.00        30
#            9       1.00      0.93      0.97        30
#           10       1.00      0.93      0.97        30
#           11       0.97      0.93      0.95        30
#           12       1.00      0.87      0.93        30
#           13       0.93      0.87      0.90        30
#           14       1.00      0.93      0.97        30
#           15       0.88      1.00      0.94        30
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        30
#           18       0.48      0.90      0.63        30
#           19       0.95      0.63      0.76        30
#
#     accuracy                           0.92       600
#    macro avg       0.95      0.92      0.93       600
# weighted avg       0.95      0.92      0.93       600
#
# linear_svm_model
# accuracy 0.9333333333333333
#               precision    recall  f1-score   support
#
#            0       0.92      0.77      0.84        30
#            1       1.00      0.97      0.98        30
#            2       1.00      1.00      1.00        30
#            3       0.91      0.97      0.94        30
#            4       0.96      0.87      0.91        30
#            5       1.00      0.93      0.97        30
#            6       1.00      1.00      1.00        30
#            7       1.00      0.97      0.98        30
#            8       1.00      1.00      1.00        30
#            9       1.00      0.97      0.98        30
#           10       1.00      0.93      0.97        30
#           11       1.00      0.93      0.97        30
#           12       1.00      0.87      0.93        30
#           13       0.97      1.00      0.98        30
#           14       1.00      0.93      0.97        30
#           15       0.97      0.97      0.97        30
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        30
#           18       0.49      0.97      0.65        30
#           19       0.90      0.63      0.75        30
#
#     accuracy                           0.93       600
#    macro avg       0.96      0.93      0.94       600
# weighted avg       0.96      0.93      0.94       600
#
# svm_model
# accuracy 0.9183333333333333
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        30
#            1       1.00      0.97      0.98        30
#            2       1.00      0.97      0.98        30
#            3       0.88      0.93      0.90        30
#            4       0.93      0.87      0.90        30
#            5       1.00      0.93      0.97        30
#            6       1.00      0.97      0.98        30
#            7       0.97      0.93      0.95        30
#            8       1.00      1.00      1.00        30
#            9       1.00      0.97      0.98        30
#           10       1.00      0.93      0.97        30
#           11       0.83      0.97      0.89        30
#           12       1.00      0.90      0.95        30
#           13       0.97      1.00      0.98        30
#           14       1.00      0.93      0.97        30
#           15       0.97      0.93      0.95        30
#           16       0.97      1.00      0.98        30
#           17       1.00      1.00      1.00        30
#           18       0.50      0.83      0.62        30
#           19       0.90      0.63      0.75        30
#
#     accuracy                           0.92       600
#    macro avg       0.93      0.92      0.92       600
# weighted avg       0.93      0.92      0.92       600
#
# knn_model
# accuracy 0.8733333333333333
#               precision    recall  f1-score   support
#
#            0       0.37      0.73      0.49        30
#            1       1.00      1.00      1.00        30
#            2       0.88      0.93      0.90        30
#            3       0.84      0.87      0.85        30
#            4       0.90      0.90      0.90        30
#            5       0.84      0.87      0.85        30
#            6       0.97      0.97      0.97        30
#            7       0.93      0.93      0.93        30
#            8       1.00      0.93      0.97        30
#            9       1.00      0.90      0.95        30
#           10       1.00      0.97      0.98        30
#           11       0.90      0.93      0.92        30
#           12       1.00      0.83      0.91        30
#           13       1.00      0.77      0.87        30
#           14       0.90      0.93      0.92        30
#           15       0.85      0.93      0.89        30
#           16       0.94      0.97      0.95        30
#           17       0.97      1.00      0.98        30
#           18       0.83      0.50      0.62        30
#           19       0.90      0.60      0.72        30
#
#     accuracy                           0.87       600
#    macro avg       0.90      0.87      0.88       600
# weighted avg       0.90      0.87      0.88       600

# %% [markdown]
# <font size="5"><b>Class for Word2vec experiment</b></font>

# %%
from gensim.models import Word2Vec
import gensim
import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

class word2vec:
    def __init__(self, X_train_tokenized, X_test_tokenized, y_train, y_test, model_path):
        self.wv = gensim.models.KeyedVectors.load_word2vec_format(model_path, binary=True)
        self.wv.init_sims(replace=True)
        self.X_train_tokenized=X_train_tokenized
        self.X_test_tokenized=X_test_tokenized
        self.y_train=y_train
        self.y_test=y_test
        
        self.evaluate_models_obj=evaluate_models()
    
    #In Bag of words we can do the word averaging of the sentence as its the most common way
    def word_averaging(self, words):
        all_words, mean = set(), []
        #print(words)
        for word in words:
            if isinstance(word, np.ndarray):
                mean.append(word)
            elif word in self.wv.vocab:
                mean.append(self.wv.syn0norm[self.wv.vocab[word].index])
                all_words.add(self.wv.vocab[word].index)

        if not mean:
            logging.warning("cannot compute similarity with no input %s", words)
            # FIXME: remove these examples in pre-processing
            return np.zeros(self.wv.vector_size,)

        mean = gensim.matutils.unitvec(np.array(mean).mean(axis=0)).astype(np.float32)
        return mean

    def word_averaging_list(self, text_list):
        return np.vstack([self.word_averaging(post) for post in text_list])
    
    #Taking means of the word vectors
    def take_word_vector_means(self):
        X_train_word_average = self.word_averaging_list(self.X_train_tokenized)
        X_test_word_average = self.word_averaging_list(self.X_test_tokenized)
        return X_train_word_average,X_test_word_average

    def run_ml_models_and_evaluate(self,X_train_word_average,X_test_word_average):
        self.evaluate_models_obj.run_ml_models(X_train_word_average,X_test_word_average,self.y_train,self.y_test)

# %%
word2vec_obj=word2vec(training_examples, test_examples, classes, classes_test, "/home/aindani/loyal/GoogleNews-vectors-negative300.bin.gz")
X_train_word_average,X_test_word_average=word2vec_obj.take_word_vector_means()
word2vec_obj.run_ml_models_and_evaluate(X_train_word_average,X_test_word_average)
# Out:
# INFO - 20:32:23: loading projection weights from /home/aindani/loyal/GoogleNews-vectors-negative300.bin.gz
# INFO - 20:34:17: loaded (3000000, 300) matrix from /home/aindani/loyal/GoogleNews-vectors-negative300.bin.gz
# INFO - 20:34:17: precomputing L2-norms of word weight vectors
# /home/aindani/.conda/envs/loyal/lib/python3.7/site-packages/ipykernel_launcher.py:25: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.vectors_norm instead).
# WARNING - 20:34:20: cannot compute similarity with no input ['ataraxy']
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input ['ishmael']
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# WARNING - 20:34:20: cannot compute similarity with no input []
# logistic_model
# /home/aindani/.conda/envs/loyal/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# accuracy 0.96
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84        30
#            1       0.97      0.97      0.97        30
#            2       1.00      1.00      1.00        30
#            3       0.97      1.00      0.98        30
#            4       0.97      0.97      0.97        30
#            5       0.97      0.97      0.97        30
#            6       1.00      1.00      1.00        30
#            7       1.00      1.00      1.00        30
#            8       0.97      0.93      0.95        30
#            9       1.00      1.00      1.00        30
#           10       0.97      0.97      0.97        30
#           11       0.88      0.93      0.90        30
#           12       1.00      0.97      0.98        30
#           13       0.96      0.90      0.93        30
#           14       1.00      0.97      0.98        30
#           15       0.88      0.97      0.92        30
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        30
#           18       0.85      0.93      0.89        30
#           19       0.97      0.93      0.95        30
#
#     accuracy                           0.96       600
#    macro avg       0.96      0.96      0.96       600
# weighted avg       0.96      0.96      0.96       600
#
# forest_model
# accuracy 0.945
#               precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86        30
#            1       0.97      0.97      0.97        30
#            2       1.00      1.00      1.00        30
#            3       0.97      1.00      0.98        30
#            4       0.97      0.93      0.95        30
#            5       0.93      0.93      0.93        30
#            6       1.00      1.00      1.00        30
#            7       1.00      1.00      1.00        30
#            8       0.97      0.93      0.95        30
#            9       1.00      1.00      1.00        30
#           10       0.81      1.00      0.90        30
#           11       0.83      1.00      0.91        30
#           12       1.00      1.00      1.00        30
#           13       0.93      0.87      0.90        30
#           14       1.00      0.93      0.97        30
#           15       0.85      0.97      0.91        30
#           16       1.00      0.97      0.98        30
#           17       1.00      1.00      1.00        30
#           18       0.90      0.63      0.75        30
#           19       0.93      0.93      0.93        30
#
#     accuracy                           0.94       600
#    macro avg       0.95      0.94      0.94       600
# weighted avg       0.95      0.94      0.94       600
#
# linear_svm_model
# accuracy 0.9766666666666667
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        30
#            1       1.00      0.97      0.98        30
#            2       1.00      1.00      1.00        30
#            3       0.97      1.00      0.98        30
#            4       0.97      0.93      0.95        30
#            5       1.00      0.97      0.98        30
#            6       1.00      1.00      1.00        30
#            7       1.00      1.00      1.00        30
#            8       1.00      0.97      0.98        30
#            9       1.00      1.00      1.00        30
#           10       1.00      1.00      1.00        30
#           11       0.94      0.97      0.95        30
#           12       1.00      1.00      1.00        30
#           13       1.00      0.97      0.98        30
#           14       1.00      0.97      0.98        30
#           15       0.94      1.00      0.97        30
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        30
#           18       0.85      0.93      0.89        30
#           19       0.97      0.93      0.95        30
#
#     accuracy                           0.98       600
#    macro avg       0.98      0.98      0.98       600
# weighted avg       0.98      0.98      0.98       600
#
# svm_model
# accuracy 0.9766666666666667
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        30
#            1       1.00      0.97      0.98        30
#            2       1.00      0.97      0.98        30
#            3       0.97      1.00      0.98        30
#            4       0.97      0.93      0.95        30
#            5       1.00      0.97      0.98        30
#            6       1.00      1.00      1.00        30
#            7       1.00      1.00      1.00        30
#            8       1.00      1.00      1.00        30
#            9       1.00      1.00      1.00        30
#           10       1.00      1.00      1.00        30
#           11       1.00      0.97      0.98        30
#           12       1.00      1.00      1.00        30
#           13       1.00      0.93      0.97        30
#           14       1.00      0.97      0.98        30
#           15       0.91      1.00      0.95        30
#           16       1.00      1.00      1.00        30
#           17       1.00      1.00      1.00        30
#           18       0.91      0.97      0.94        30
#           19       0.88      0.93      0.90        30
#
#     accuracy                           0.98       600
#    macro avg       0.98      0.98      0.98       600
# weighted avg       0.98      0.98      0.98       600
#
# knn_model
# accuracy 0.9233333333333333
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79        30
#            1       1.00      0.97      0.98        30
#            2       0.97      0.97      0.97        30
#            3       0.87      0.87      0.87        30
#            4       0.88      0.93      0.90        30
#            5       0.83      0.97      0.89        30
#            6       0.94      1.00      0.97        30
#            7       0.97      0.97      0.97        30
#            8       1.00      0.97      0.98        30
#            9       1.00      1.00      1.00        30
#           10       0.97      0.97      0.97        30
#           11       0.76      0.97      0.85        30
#           12       0.97      0.97      0.97        30
#           13       1.00      0.93      0.97        30
#           14       1.00      0.93      0.97        30
#           15       0.91      0.97      0.94        30
#           16       0.97      1.00      0.98        30
#           17       1.00      1.00      1.00        30
#           18       0.67      0.53      0.59        30
#           19       1.00      0.80      0.89        30
#
#     accuracy                           0.92       600
#    macro avg       0.92      0.92      0.92       600
# weighted avg       0.92      0.92      0.92       600
